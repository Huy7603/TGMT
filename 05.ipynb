# %%
# Import lớp Image
from PIL import Image
from imagetools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/Admin/TGMT/3.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)

# Resize
# img = img.resize((250,250))

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=639x360>

# %%
# Xoay ảnh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=639x360>

# %%
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=639x360>

# %%
# Transpose ảnh
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=360x639>

# %%
# Transpose ảnh
transposed_image = transposed_image.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=639x360>
